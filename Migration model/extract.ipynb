# %%
import pandas as pd
import csv

# Load dataset
file_path = r"C:\Users\Deshan\Documents\Github\Bird-Range-Prediction\Migration model\data\migration_data.csv"
df = pd.read_csv(file_path)

# Get unique LOCALITY values
unique_localities = df['LOCALITY'].dropna().unique()
unique_localities_sorted = sorted(unique_localities)

# Format and print with quotes and commas
formatted = ', '.join(f'"{loc}"' for loc in unique_localities_sorted)

# Print wrapped across lines (optional for readability)
print("\nFormatted Unique Localities:\n")
print(formatted)

with open("cleaned_unique_localities.csv", 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f, quoting=csv.QUOTE_ALL)
    writer.writerow(unique_localities_sorted)


print("\n📝 Saved to 'cleaned_unique_localities.csv'")
# Out:
# Formatted Unique Localities:
#
# "Agunukolapelessa Kepu Ela", "Airport Entrance Road Mattala Southern Province", "Airport Entrance Road Southern Province", "Alikatupalassa Yala National Park Block I Katagamuwa Entrance Southern Province", "Amaduwa Beach  Yala", "Amanwella Beach", "Amanwella New Land", "Ambilakala Lagoon Southern Province", "Ambilikala Kalapuwa Southern Province", "Ampitiya Lake Beliatta Southern Province", "Anantara Peace Haven Tangalle Resort", "Anantara Peace Haven Tangalle Resort Goyambokka", "Anantara Peace Heaven", "Anantara Peace Heaven Tangalle Resort Tangalle Southern Province", "Andarawewa Highway Exit Road", "Andarawewa Interchange Southern Expressway Southern Province", "Atulla Kalapuwa", "Atulla Lagoon", "Ayurvedic Hospital Gardens Badagiriya Hambantota  Southern Province", "B Kirinda Road Southern Province", "B Kirinda Southern Province", "B Kirinda Southern Province  Bundala National Park", "B New Road Hambantota", "B Tissamaharama Southern Province  yala National park", "B_Bundala_NP_Unnamed Road Southern Province", "B_Unnamed Road Southern Province", "B__Bundala_NP_Unnamed Road Southern Province", "Back of Beyond", "Back of Beyond Kahandamodera Ranna Sri Lanka", "Back of Beyond Kahandaramodara", "Badagiriya  Keliyawalana Tanks Southern Province", "Badagiriya Tank Southern Province", "Bandagiriya  Keliyawalana Wewa Connecting Canal Southern Province", "Bandagiriya Lake Southern Province", "Bandagiriya Southern Province", "Bandu Wewa Bundala Village Southern Province", "Beach Road Kirinda Southern Province", "Beauty Of Nature Guesthouse Kirinda Southern Province", "Beliatta  Walasmulla Road Southern Province", "Beliatta Railway Station Southern Province", "Beragama Lake", "Bird park resort Hambantota", "Blue Wild", "Boitare Tank Thangalle", "Border Of Bundala", "Buckingham Place", "Buckingham Place Hotel Tangalle", "Buffalo Pens in Thissa TankSanding Amazing Road Tissamaharama Southern Province", "Bun salad before entrance", "Bundabla Southern Province", "Bundala", "Bundala  Embilikala Lagoon", "Bundala  Salterns", "Bundala  Uraniya", "Bundala  Wilmenna Sanctuary", "Bundala Entrance to Saltern", "Bundala Flamingo Cottages", "Bundala Freshwater Marsh", "Bundala Junction Wetland", "Bundala Kalapuwa  Bundala Village", "Bundala Kanishta Vidhyalaya Weligatta Southern Province", "Bundala Kirinda Road Southern Province", "Bundala Lagoon", "Bundala Levaya vicinity", "Bundala Maha Lewaya  Surrounding Area", "Bundala NP", "Bundala NP    East", "Bundala NP Between ticketing Office  Entrance Southern Province", "Bundala NP General", "Bundala NP Southern Province", "Bundala National Park", "Bundala National Park  East Section", "Bundala National Park  Saltern", "Bundala National Park  Southern Section", "Bundala National Park  Surrounding Area", "Bundala National Park Kirinda Southern Province", "Bundala National Park Office", "Bundala National Park Southern Province", "Bundala National Park Sri Lanka", "Bundala National Park Stop", "Bundala National Park Tank No", "Bundala National Park Weligaththa Junction to Bundala Village Southern Province", "Bundala National Park approach road", "Bundala National Park entrance", "Bundala National ParkSouthern province", "Bundala National park", "Bundala Np Unnamed Road Southern Province", "Bundala Paddy fields", "Bundala Park Road", "Bundala Park Road Up To Entrance", "Bundala Road Weligatta Southern Province", "Bundala Saltern", "Bundala Saltern area", "Bundala Salterns", "Bundala Village  Southern Province", "Bundala Village  Surrounding Area", "Bundala Village Edge", "Bundala Village Paddyfields", "Bundala Village Wetland Southern Province", "Bundala access road", "Bundala area  outside the park", "Bundala flamingo cottage", "Bundala lagoon", "Bundala lewaya", "Bundala national park", "Bundala salt pan area", "Bundala salt pans  ENE  NNW along road", "Bundala saltern up to Palugasmandiya camping site", "Bundala village forest", "Buthawa Wewa", "Buthawa Yala National park", "CCR Tlssamaharama", "Caus ...
#
# 📝 Saved to 'cleaned_unique_localities.csv'

# %%
# Step 1: Install required librar
# Step 2: Import libraries
import pandas as pd
import re
from rapidfuzz import process, fuzz

# Step 3: Load the dataset
file_path = r"C:\Users\Deshan\Documents\Github\Bird-Range-Prediction\Migration model\data\migration_data.csv"
df = pd.read_csv(file_path)

# Step 4: Normalize LOCALITY strings
def normalize(text):
    text = str(text).lower().strip()
    text = re.sub(r'\s+', ' ', text)                      # remove extra spaces
    text = re.sub(r'[^\w\s]', '', text)                   # remove punctuation
    text = re.sub(r'\bsouthern province\b', '', text)     # remove common suffixes
    text = re.sub(r'\bsri lanka\b', '', text)
    text = re.sub(r'\broad\b', '', text)
    text = re.sub(r'\bentrance\b', '', text)
    return text.strip()

df['LOCALITY_CLEAN'] = df['LOCALITY'].apply(normalize)

# Step 5: Fuzzy matching to group similar localities
unique_values = df['LOCALITY_CLEAN'].dropna().unique()
mapped = {}

for val in unique_values:
    if val in mapped:
        continue
    matches = process.extract(val, unique_values, scorer=fuzz.token_sort_ratio, limit=None)
    for match_val, score, _ in matches:
        if score >= 90:
            mapped[match_val] = val  # Map all close matches to the base value

# Step 6: Map to grouped values
df['LOCALITY_GROUPED'] = df['LOCALITY_CLEAN'].map(mapped)

# Step 7: Get the final unique locality list
final_localities = sorted(df['LOCALITY_GROUPED'].dropna().unique())

# Step 8: Print unique localities
print("✅ Unique Cleaned Localities:")
for loc in final_localities:
    print(loc)

# Step 9: Optional – Save to CSV
pd.Series(final_localities).to_csv("cleaned_unique_localities.csv", index=False)
print("\n📝 Saved to 'cleaned_unique_localities.csv'")
# Out:
# ✅ Unique Cleaned Localities:
#
# agunukolapelessa kepu ela
# airport
# airport   mattala
# alikatupalassa yala national park block i katagamuwa
# amaduwa beach yala
# amanwella beach
# amanwella new land
# ambilakala lagoon
# ambilikala kalapuwa
# ampitiya lake beliatta
# anantara peace haven tangalle resort
# anantara peace haven tangalle resort goyambokka
# anantara peace heaven
# anantara peace heaven tangalle resort tangalle
# andarawewa highway exit
# andarawewa interchange southern expressway
# atulla kalapuwa
# atulla lagoon
# ayurvedic hospital gardens badagiriya hambantota
# b kirinda
# b new  hambantota
# b tissamaharama  yala national park
# b_bundala_np_unnamed
# b_unnamed
# back of beyond
# back of beyond kahandamodera ranna
# back of beyond kahandaramodara
# badagiriya keliyawalana tanks
# badagiriya tank
# bandagiriya
# bandagiriya keliyawalana wewa connecting canal
# bandagiriya lake
# bandu wewa bundala village
# beauty of nature guesthouse kirinda
# behind debarawara lake sandungama
# beliatta railway station
# beliatta walasmulla
# beragama lake
# bird park resort hambantota
# blue wild
# boitare tank thangalle
# border of bundala
# buckingham place
# buckingham place hotel tangalle
# buffalo pens in thissa tanksanding amazing  tissamaharama
# bun salad before
# bundala
# bundala  to saltern
# bundala  weligatta
# bundala access
# bundala area outside the park
# bundala embilikala lagoon
# bundala flamingo cottage
# bundala freshwater marsh
# bundala junction wetland
# bundala kalapuwa bundala village
# bundala kanishta vidhyalaya weligatta
# bundala kirinda
# bundala lagoon
# bundala levaya vicinity
# bundala lewaya
# bundala maha lewaya surrounding area
# bundala national park
# bundala national park approach
# bundala national park east section
# bundala national park kirinda
# bundala national park office
# bundala national park saltern
# bundala national park southern section
# bundala national park stop
# bundala national park surrounding area
# bundala national park tank no
# bundala national park weligaththa junction to bundala village
# bundala national parksouthern province
# bundala np
# bundala np between ticketing office
# bundala np east
# bundala np general
# bundala np unnamed
# bundala paddy fields
# bundala park
# bundala park  up to
# bundala salt marsh
# bundala salt pan area
# bundala salt pans ene nnw along
# bundala saltern area
# bundala saltern up to palugasmandiya camping site
# bundala salterns
# bundala uraniya
# bundala village
# bundala village edge
# bundala village forest
# bundala village paddyfields
# bundala village surrounding area
# bundala village wetland
# bundala wilmenna sanctuary
# buthawa wewa
# buthawa yala national park
# causeway near park office
# ccr tlssamaharama
# ceylon wild safari bushwalk path kochchipothana yala katharagama
# charia
# chena huts yala national park
# cinnamon wild
# cinnamon wild hotel
# cinnamon wild hotel palatupana
# cinnamon wild hotel yala
# cinnamon wild lake
# cinnamon wild to galge
# cinnamon wild yala
# cinnamon wild yala national park
# colombo galle hambantota wellawaya highway hambantota
# colombo galle hambantota wellawaya highway tangalle
# colombo galle hambantota wellawaya highway wirawila
# colombo galle hambantota wellawaya highway wirawila  wirawila lake
# dambagahawala lake
# darshanawewa junction yala national park block i katagamuwa
# debara wewa lake
# debara wewa tissa wewa lakes
# debarawewa
# debarawewa krindi oya river east to lakeside cabanas
# debarawewa lake
# debarawewa lake surrounding area
# debarawewa tank vicinity
# diganwala palatupana yala  yala national park blocki
# district secretariat hambanthota
# divulpitiya lake
# dole aranya kithulagoda pitadeniya pallekanda southern
# double tree hilton wirawila
# doubletree hilton
# dry zone botanic gardens hambanthota
# dry zone botanical garden
# dvordme site mattala rajapaksa international airport
# e
# e roadside
# egoswargarajje
# elephant reach hotel
# embilikala bundala national park
# embilikala kalapuwa wetland bundula national park
# embilikala lagoon
# embilikala to park office bundala national park
# embilikalalsouthern province
# fishing village pallemalala hambantota
# flameback
# flameback lodge
# flamingo cottage
# forest area bundala national park
# gal wala home walasmulla southern
# galpotta  wakkariya junction bandagiriya
# galpottha  wakkariya junction badagiriya hambantota
# gemunupura debarawewa
# getamanna  beliatta
# godakalapuwa kirinda palatupana yala
# godakalapuwa ruhuna np
# godawaya
# gona widda wewa bundala sanctuary
# goyam bay
# goyambokka තගලල දකණ පළත palm paradice hotel
# grand hotel halabana
# great lake villa weerawila lake
# gurupokuna kalametiya
# gurupokuna rock kalametiya
# hambanthota kalu dodol shops
# hambanthota maha lewaya
# hambantota
# hambantota bundala
# hambantota mirijjawila dry zone botanical gardens
# hambantota salt pans
# hamlet
# heenwewa bungalow
# hibiscus garden hotel tissamaharama
# hri airport
# hummanaya blow hole kudawella
# hungama gurupokuna
# hungama post office
# in front of the guest house
# isuru villa beliaththa
# jetwing yala  palatupana
# jetwing yala hotel
# jetwing yala palatupana beach
# jetwing yala resort
# jul am
# kadurupokuna
# kahandamodara
# kalamatiya  kalametiya
# kalametiya
# kalametiya bird sanctuary
# kalametiya lagoon kalametiya
# kalametiya plains
# kalametiya sancruary
# kalametiya sanctuary gurupokuna side
# kalametiya sanctuary lunama lagoon
# kalametiya village southern
# karagan lewaya
# karagan lewaya hambanthota
# katagamuwa wildlife sanctuary
# kataragama situlpawwa
# keliyapura gonnoruwa
# keliyawalana wewa
# kirinda
# kirinda  cinnamon wild hotel
# kirinda beach
# kirinda lagoon
# kirinda palatupana shrubs patch
# kirinda palatupana yala
# kirinda palatupana yala   yala national park block
# kirinda palatupana yala  kirinda
# kirinda palatupana yala  kirinda  cozey yala
# kirinda palatupana yala  palatupana
# kirinda situlpawwa
# kirinda situlpawwa katharagama
# kirindapalatupanayala  yala national park block
# kirindayala roadpalatupana
# kithala resort
# kithala resort tissamaharama
# kl park
# koholankal lewaya
# koma wewa yala national park block i
# koragaha lodge
# koravakwala tank yala national park block i katagamuwa
# kotasiyabale yala national park
# krindi oya
# kulu safari
# kulu safaris katagamuwa
# lagoon inn
# lagoon paradise beach resort
# lake
# lake  tissamaharama
# lake ibis n e
# lake tissa eastnorth
# lake view cottage tissamaharama
# lanka salt circuit bungalow
# lavish eco lodge to lake
# laxman rajapaksha
# leopard corridor palatupana
# lin thuna area vicinity
# lunugamwehera
# lunugamwehera airport
# lunugamwehera highway
# lunungamwehera katarangama
# madunagala hot water spring
# madunahala forest
# mahaseelawa
# mahaseelawa lagoon
# mahasenpura tissamaharama
# mahawala lagoon
# malala modara
# maliththanpelessa rock outcrop wedihitikanda forest reserve katharagama
# mamadala
# mangrove beach chalets
# marakolliya tangalle
# mattala
# mattala interchange southern expressway
# mattala rajapaksa international airport
# mawalla lagoon
# mawalla lagoon morakatiyara
# mayasha residence uddakandara sithulpawwa  tissamaharama
# medilla
# medilla tangalle
# meegahajandura suriyawewa
# menikganga rest stop yala national park block i
# menikganga river cross warahana yala national park block i katagamuwa
# menikganga to katagamuwa sanctuary yala block i
# mirijjawila
# mirijjawila lewaya
# mirissa
# modarawana okewela
# modarawana okewela southern
# moms kitchen tissamaharama
# monaragala district uva
# moon light guest house
# morakatiyara
# mulkirigala rock monastry
# muruthawela lake
# muruthawela tank
# nakulugamuwa paddy fields
# nathuwala walasmulla southern
# nature lovers resort kirinda
# nd plain kalametiya
# nd plainkalamatiya  kalametiya
# netolpitiya
# netolpitiya rekawa
# new buthawa wild life bungalow yala national park
# nidangala beach
# nidangala beach kirinda
# nil sisila palatupana
# nimalawa temple  kirinda
# nonagama
# nov
# nov am
# nov pm
# nugasewana campsite vicinity
# ocean cottage
# oceans edge
# old buthawa wildlife bungalow yala national park block
# padawkema mattala
# paddy research station ambalantota
# palatupana
# palatupana  cinnomon wild
# palatupana area
# palatupana beach yala
# palatupana lagoon
# palatupana lewaya
# palatupana saltern
# palatupana saltern bungalow
# palatupana salthern bungalow sea side
# palatupana wetland
# pallamelala wela
# pallemalala
# pallemalala wewa
# pannegamuwa lake
# pannegamuwa tank
# patanangala beach
# patanangala resthouse
# patanangala wewa patanangala resthouse  yala national park block
# pattamaluwa juntion
# pattiyawala yala national park
# peacock reach hotel tissamaharama
# pemdas vila yala national park block i
# pennegamuwa wirawila
# pond rekawa
# ponds next to ticket office
# punchi akurugoda tissamaharamaya
# puwakdandawa
# rajapuragodaudadeniya  walasmulla
# ranawaranawa lake
# ranna rivermouth kahandamodera beach ranna
# ranna southern express way
# rannalake near green parrot hotel
# rannameadow near mandala villas
# rannariver mouth near kahandamodara beach
# really really secret beach
# rekawa
# rekawa lagoon
# rekawa marsh
# rekawa village surrounding areas
# rekawawetlands
# ridiyagama safari park
# ridiyagamaunnamed
# river walk near lake debawarawa
# riverside hotels
# rota wewa bundala village
# roverr birding tissamaharama
# rumba viharaya
# sahanagama rd
# salter faced restaurent area
# saltern bunglow to wilmannar sanctuary in side the sanctuary
# saltlake near kalametiya
# samikuliya wewa
# sandagirigama sithulpawwa
# sandungama  tissamaharama
# saradha lagoon view
# seadawatta wirawila
# senasuma wetland
# shangrila hambantota hotel
# shangrila resort hambantota
# shangrilas hambantota
# sithulpahuwa monastery kirindasitulpawwa  situlpawwa
# sithulpawwa
# slow new tangalle  tangalle
# smal pond near rekawa
# southern expressway
# southern provincecolombo galle hambantota wellawaya
# southern provincekirindapalatupanayala
# sri kawanthissa vocational training center
# sri lankaekho safari tissa
# st plainkalamatiya  kalametiya
# sw
# tangalla marshes
# tangalla prowincja południowa
# tangalla rest house
# tangalle
# tangalle beach
# tangalle paddy fields
# tangalle paddyfields west side
# tangalle tangalle
# tangalle villa
# tangalle wella
# taragala chalets tangalle
# taru villas mawella
# td
# telulla archaeological site
# tern dry zone field station
# thalgasmankada yala national park
# thanamalwila tranquil wild
# thangalle marsh
# thanjanagar mahasenpura tissamaharama
# thissa kataragama  chef lady
# thissa reservoir flood zone thissamaharama
# thissamahara surroundings
# thissamaharama stupa temple
# tissa
# tissa  debarawewa
# tissa  hungama
# tissa  tissamaharama
# tissa kirinde
# tissa lake
# tissa lake area
# tissa lake flying fox hotspot
# tissa lake north
# tissa maharama
# tissa rd weligatta southern
# tissa tank tissamaharama
# tissa wetland tissamaharamaya
# tissamaharam  hambantota
# tissamaharam  weligatta
# tissamaharama
# tissamaharama general
# tissamaharama general area
# tissamaharama lakes around
# tissamaharama to bundala np
# tissamaharama_chaarya hotel spa
# to the bird park
# tranquill wild
# treasure rock guest house
# treasure rock kirinda
# tribe yala
# tribe yala resort
# turtle bay hotel kalametiya
# turtle bay kalametiya
# turtle paradise hotel
# turtle point beach
# turtle watch rekawa
# turtles view resort
# uciars weligatta
# uda maththala
# udamalala tissamaharam
# udawila wewa
# udukiriwala wewa
# unakuruwa
# unnamed
# unnamed   banduwewa
# unnamed   ranketha eco safari
# unnamed   yala national park block
# unnamed  andarawewa
# unnamed  hambantota
# unnamed  mahasenpura
# urania national park area
# urania village from the saltern bunglow
# uraniya wewa surrounding vicinity
# ussangoda
# ussangoda beach
# ussangoda national park
# ussangoda national park ambalantota
# villa tanderra
# voccational training centre tissamaharama
# wadula lodge
# wakamulla
# wakkariya junction badagiriya hambantota
# walasmulla
# walatta villa
# waligatta to bundala
# waligatta wewa tissamaharam
# warahana thalgasmankada
# warapitiya lake
# wedasitikanda forest reserve border malittanpelessa wewa
# weerawila dam
# weerawila hilton hotel
# weerawila lake southern provincepannegamuwatissakataragama
# weerawila tank
# weliaragoda wetland
# weligatta
# weligatta junction from the saltern bungalow
# welmalkema yala np
# wewa unnamed
# whispering house
# wilapalawa yala national park
# wild coast tented lodge yala
# wild heaven hotel
# wild lotus
# wild lotus yala
# wild trails yala
# will anna bundala
# wilmanna sanctuary
# wilmanna sanctuary along the kirinda
# wirawila
# wirawila lake
# wirawila tissa sanctuary
# wnps yala bungalow
# wnps yala bungalow palatupana
# yahangala archaeological ruine site hambantota
# yala
# yala  roads around
# yala beach nature resort palatupana
# yala block
# yala block general
# yala buffer zone
# yala entry gate
# yala jetwing
# yala national park
# yala national park block i katagamuwa
# yala national park block i palatupana
# yala national park block i sathmanga modaragala to pemdasvila
# yala national park block ii
# yala national park block v palatupana via heenwewa section katagamuwa  upto koma wewa
# yala national park general
# yala national park hambantota
# yala national park katagamuwa
# yala national park katagamuwa  kataragama
# yala national park palatupana
# yala national parksri lanka
# yala natl park block i
# yala new buthawa
# yala np
# yala np  area
# yala np block
# yala np block i from y junction to sithulpawwa
# yala np katagamuwa
# yala np katagamuwa to akasa chaithya
# yala npkatagamuwa
# yala nppatanangala beach picnic area
# yala old buthawa
# yala old buthawa bungalow
# yala palatupana
# yala palatupana  area
# yala palatupana entarnce to mahaseelawa
# yala saltern palatupana
# yala surroundings near jeep yard
# yala to setulpawwa
# yala wewa reservoir yala national park block i
# yalla
# yoda kandiya tank
# yoda lake
# yoda lake tissa
# yodha wewa
# zuidelijke provincie
# භමඛනතට දකණ පළත
# 南部省
# 南部省 南部省
#
# 📝 Saved to 'cleaned_unique_localities.csv'

# %%
import pandas as pd
import re
from rapidfuzz import fuzz, process

# Load your CSV
file_path = r"C:\Users\Deshan\Documents\Github\Bird-Range-Prediction\Migration model\data\migration_data.csv"
df = pd.read_csv(file_path)

# Step 1: Normalize locality names
def normalize(text):
    text = str(text).lower()
    text = re.sub(r'\s+', ' ', text)  # remove extra spaces
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    return text.strip()

df['LOCALITY_CLEAN'] = df['LOCALITY'].apply(normalize)

# Step 2: Fuzzy cluster similar names
unique_names = df['LOCALITY_CLEAN'].dropna().unique().tolist()
representatives = []
manual_mappings = {}

for name in unique_names:
    # Skip if already mapped
    if name in manual_mappings:
        continue

    # Use the current name as the group representative
    representative = name
    representatives.append(representative)

    # Find similar names
    matches = process.extract(representative, unique_names, scorer=fuzz.token_sort_ratio, limit=None)
    for match_name, score, _ in matches:
        if score >= 90:  # high similarity threshold
            manual_mappings[match_name] = representative

# Step 3: Reverse mapping to get: {variant: "Proper Name"}
reverse_mapping = {}
for variant, rep in manual_mappings.items():
    original_variants = df[df['LOCALITY_CLEAN'] == variant]['LOCALITY'].values
    if len(original_variants) > 0:
        reverse_mapping[original_variants[0]] = df[df['LOCALITY_CLEAN'] == rep]['LOCALITY'].value_counts().idxmax()

# Step 4: Print the final manual_mappings
print("manual_mappings = {")
for k, v in sorted(reverse_mapping.items()):
    print(f'    "{k}": "{v}",')
print("}")
# Out:
# manual_mappings = {
#     "Agunukolapelessa Kepu Ela": "Agunukolapelessa Kepu Ela",
#     "Airport Entrance Road Mattala Southern Province": "Airport Entrance Road Southern Province",
#     "Airport Entrance Road Southern Province": "Airport Entrance Road Southern Province",
#     "Alikatupalassa Yala National Park Block I Katagamuwa Entrance Southern Province": "Alikatupalassa Yala National Park Block I Katagamuwa Entrance Southern Province",
#     "Amaduwa Beach  Yala": "Amaduwa Beach  Yala",
#     "Amanwella Beach": "Amanwella Beach",
#     "Amanwella New Land": "Amanwella New Land",
#     "Ambilakala Lagoon Southern Province": "Ambilakala Lagoon Southern Province",
#     "Ambilikala Kalapuwa Southern Province": "Ambilikala Kalapuwa Southern Province",
#     "Ampitiya Lake Beliatta Southern Province": "Ampitiya Lake Beliatta Southern Province",
#     "Anantara Peace Haven Tangalle Resort": "Anantara Peace Haven Tangalle Resort",
#     "Anantara Peace Haven Tangalle Resort Goyambokka": "Anantara Peace Haven Tangalle Resort Goyambokka",
#     "Anantara Peace Heaven": "Anantara Peace Heaven",
#     "Anantara Peace Heaven Tangalle Resort Tangalle Southern Province": "Anantara Peace Heaven Tangalle Resort Tangalle Southern Province",
#     "Andarawewa Highway Exit Road": "Andarawewa Highway Exit Road",
#     "Andarawewa Interchange Southern Expressway Southern Province": "Andarawewa Interchange Southern Expressway Southern Province",
#     "Atulla Kalapuwa": "Atulla Kalapuwa",
#     "Atulla Lagoon": "Atulla Lagoon",
#     "Ayurvedic Hospital Gardens Badagiriya Hambantota  Southern Province": "Ayurvedic Hospital Gardens Badagiriya Hambantota  Southern Province",
#     "B Kirinda Road Southern Province": "Beach Road Kirinda Southern Province",
#     "B Kirinda Southern Province": "B Kirinda Southern Province",
#     "B Kirinda Southern Province  Bundala National Park": "Bundala National Park Kirinda Southern Province",
#     "B New Road Hambantota": "B New Road Hambantota",
#     "B Tissamaharama Southern Province  yala National park": "B Tissamaharama Southern Province  yala National park",
#     "B_Bundala_NP_Unnamed Road Southern Province": "B_Bundala_NP_Unnamed Road Southern Province",
#     "B_Unnamed Road Southern Province": "B_Unnamed Road Southern Province",
#     "B__Bundala_NP_Unnamed Road Southern Province": "B_Bundala_NP_Unnamed Road Southern Province",
#     "Back of Beyond": "Back of Beyond",
#     "Back of Beyond Kahandamodera Ranna Sri Lanka": "Back of Beyond Kahandamodera Ranna Sri Lanka",
#     "Back of Beyond Kahandaramodara": "Back of Beyond Kahandaramodara",
#     "Badagiriya  Keliyawalana Tanks Southern Province": "Badagiriya  Keliyawalana Tanks Southern Province",
#     "Badagiriya Tank Southern Province": "Bandagiriya Southern Province",
#     "Bandagiriya  Keliyawalana Wewa Connecting Canal Southern Province": "Bandagiriya  Keliyawalana Wewa Connecting Canal Southern Province",
#     "Bandagiriya Lake Southern Province": "Bandagiriya Southern Province",
#     "Bandagiriya Southern Province": "Bandagiriya Southern Province",
#     "Bandu Wewa Bundala Village Southern Province": "Bandu Wewa Bundala Village Southern Province",
#     "Beach Road Kirinda Southern Province": "Beach Road Kirinda Southern Province",
#     "Beauty Of Nature Guesthouse Kirinda Southern Province": "Beauty Of Nature Guesthouse Kirinda Southern Province",
#     "Beliatta  Walasmulla Road Southern Province": "Beliatta  Walasmulla Road Southern Province",
#     "Beliatta Railway Station Southern Province": "Beliatta Railway Station Southern Province",
#     "Beragama Lake": "Beragama Lake",
#     "Bird park resort Hambantota": "Bird park resort Hambantota",
#     "Blue Wild": "Blue Wild",
#     "Boitare Tank Thangalle": "Boitare Tank Thangalle",
#     "Border Of Bundala": "Border Of Bundala",
#     "Buckingham Place": "Buckingham Place",
#     "Buckingham Place Hotel Tangalle": "Buckingham Place Hotel Tangalle",
#     "Buffalo Pens in Thissa TankSanding Amazing Road Tissamaharama Southern Province": "Buffalo Pens in Thissa TankSanding Amazing Road Tissamaharama Southern Province",
#     "Bun salad before entrance": "Bun salad before entrance",
#     "Bundabla Southern Province": "Bundala NP Southern Province",
#     "Bundala  Embilikala Lagoon": "Bundala  Embilikala Lagoon",
#     "Bundala  Uraniya": "Bundala  Uraniya",
#     "Bundala  Wilmenna Sanctuary": "Bundala  Wilmenna Sanctuary",
#     "Bundala Entrance to Saltern": "Bundala Entrance to Saltern",
#     "Bundala Flamingo Cottages": "Bundala flamingo cottage",
#     "Bundala Freshwater Marsh": "Bundala Freshwater Marsh",
#     "Bundala Junction Wetland": "Bundala Junction Wetland",
#     "Bundala Kalapuwa  Bundala Village": "Bundala Kalapuwa  Bundala Village",
#     "Bundala Kanishta Vidhyalaya Weligatta Southern Province": "Bundala Kanishta Vidhyalaya Weligatta Southern Province",
#     "Bundala Kirinda Road Southern Province": "Bundala Kirinda Road Southern Province",
#     "Bundala Lagoon": "Bundala Lagoon",
#     "Bundala Levaya vicinity": "Bundala Levaya vicinity",
#     "Bundala Maha Lewaya  Surrounding Area": "Bundala Maha Lewaya  Surrounding Area",
#     "Bundala NP": "Bundala NP",
#     "Bundala NP    East": "Bundala NP    East",
#     "Bundala NP Between ticketing Office  Entrance Southern Province": "Bundala NP Between ticketing Office  Entrance Southern Province",
#     "Bundala NP General": "Bundala NP General",
#     "Bundala NP Southern Province": "Bundala NP Southern Province",
#     "Bundala National Park": "Bundala National Park",
#     "Bundala National Park  East Section": "Bundala National Park  East Section",
#     "Bundala National Park  Saltern": "Bundala National Park  Saltern",
#     "Bundala National Park  Southern Section": "Bundala National Park  Southern Section",
#     "Bundala National Park  Surrounding Area": "Bundala National Park  Surrounding Area",
#     "Bundala National Park Kirinda Southern Province": "Bundala National Park Kirinda Southern Province",
#     "Bundala National Park Office": "Bundala National Park Office",
#     "Bundala National Park Southern Province": "Bundala National Park Kirinda Southern Province",
#     "Bundala National Park Sri Lanka": "Bundala National Park Sri Lanka",
#     "Bundala National Park Stop": "Bundala National Park Stop",
#     "Bundala National Park Tank No": "Bundala National Park Tank No",
#     "Bundala National Park Weligaththa Junction to Bundala Village Southern Province": "Bundala National Park Weligaththa Junction to Bundala Village Southern Province",
#     "Bundala National Park approach road": "Bundala National Park approach road",
#     "Bundala National Park entrance": "Bundala National Park entrance",
#     "Bundala National ParkSouthern province": "Bundala National ParkSouthern province",
#     "Bundala Np Unnamed Road Southern Province": "Bundala Np Unnamed Road Southern Province",
#     "Bundala Paddy fields": "Bundala Paddy fields",
#     "Bundala Park Road": "Bundala Park Road",
#     "Bundala Park Road Up To Entrance": "Bundala Park Road Up To Entrance",
#     "Bundala Road Weligatta Southern Province": "Bundala Road Weligatta Southern Province",
#     "Bundala Saltern": "Bundala Saltern",
#     "Bundala Saltern area": "Bundala Saltern area",
#     "Bundala Salterns": "Bundala Saltern",
#     "Bundala Village  Southern Province": "Bundala Village  Southern Province",
#     "Bundala Village  Surrounding Area": "Bundala Village  Surrounding Area",
#     "Bundala Village Edge": "Bundala Village Edge",
#     "Bundala Village Paddyfields": "Bundala Village Paddyfields",
#     "Bundala Village Wetland Southern Province": "Bundala Village Wetland Southern Province",
#     "Bundala access road": "Bundala access road",
#     "Bundala area  outside the park": "Bundala area  outside the park",
#     "Bundala flamingo cottage": "Bundala flamingo cottage",
#     "Bundala lewaya": "Bundala lewaya",
#     "Bundala salt pan area": "Bundala salt pan area",
#     "Bundala salt pans  ENE  NNW along road": "Bundala salt pans  ENE  NNW along road",
#     "Bundala saltern up to Palugasmandiya camping site": "Bundala saltern up to Palugasmandiya camping site",
#     "Bundala village forest": "Bundala village forest",
#     "Buthawa Wewa": "Buthawa Wewa",
#     "Buthawa Yala National park": "Buthawa Yala National park",
#     "CCR Tlssamaharama": "CCR Tlssamaharama",
#     "Causeway near Park Office": "Causeway near Park Office",
#     "Ceylon Wild Safari Bushwalk Path Kochchipothana Yala  Katharagama Southern Province": "Ceylon Wild Safari Bushwalk Path Kochchipothana Yala  Katharagama Southern Province",
#     "Charia": "Charia",
#     "Chena Huts Yala National Park": "Chena Huts Yala National Park",
#     "Cinnamon Wild": "Cinnamon Wild",
#     "Cinnamon Wild  Lake": "Cinnamon Wild  Lake",
#     "Cinnamon Wild Hotel": "Cinnamon Wild Hotel",
#     "Cinnamon Wild Hotel Palatupana Southern Province": "Palatupana Southern Province  cinnomon  Wild",
#     "Cinnamon Wild Hotel Yala": "Cinnamon Wild Hotel Yala",
#     "Cinnamon Wild To Galge": "Cinnamon Wild To Galge",
#     "Cinnamon Wild Yala": "Cinnamon wild yala",
#     "Cinnamon Wild Yala National Park": "Cinnamon Wild Yala National Park",
#     "Cinnamon Wild Yala Southern Province": "Cinnamon Wild Yala Southern Province",
#     "Colombo  Galle  Hambantota  Wellawaya Highway Hambantota Southern Province": "Colombo  Galle  Hambantota  Wellawaya Highway Hambantota Southern Province",
#     "Colombo  Galle  Hambantota  Wellawaya Highway Ranna Southern Province": "Colombo  Galle  Hambantota  Wellawaya Highway Ranna Southern Province",
#     "Colombo  Galle  Hambantota  Wellawaya Highway Southern Province": "Colombo  Galle  Hambantota  Wellawaya Highway Hambantota Southern Province",
#     "Colombo  Galle  Hambantota  Wellawaya Highway Tangalle Southern Province": "Colombo  Galle  Hambantota  Wellawaya Highway Tangalle Southern Province",
#     "Colombo  Galle  Hambantota  Wellawaya Highway Wirawila Southern Province": "Colombo  Galle  Hambantota  Wellawaya Highway Wirawila Southern Province",
#     "Colombo  Galle  Hambantota  Wellawaya Highway Wirawila Southern Province   Wirawila Lake": "Colombo  Galle  Hambantota  Wellawaya Highway Wirawila Southern Province",
#     "DVORDME Site  Mattala Rajapaksa International Airport": "DVORDME Site  Mattala Rajapaksa International Airport",
#     "Dambagahawala Lake": "Dambagahawala Lake",
#     "Darshanawewa Junction Yala National Park Block I Katagamuwa Entrance Southern Province": "Darshanawewa Junction Yala National Park Block I Katagamuwa Entrance Southern Province",
#     "Debara Wewa  Tissa Wewa Lakes": "Debara Wewa  Tissa Wewa Lakes",
#     "Debara Wewa Lake": "Debara Wewa Lake",
#     "Debarawewa": "Debarawewa",
#     "Debarawewa Krindi Oya river east to Lakeside Cabanas": "Debarawewa Krindi Oya river east to Lakeside Cabanas",
#     "Debarawewa Lake": "Debarawewa Lake",
#     "Debarawewa Lake  surrounding area": "Debarawewa Lake  surrounding area",
#     "Debarawewa Southern Province": "Debarawewa Southern Province",
#     "Debarawewa tank  vicinity": "Debarawewa tank  vicinity",
#     "Diganwala Palatupana  Yala Road Yala National Park BlockI Southern Province": "Diganwala Palatupana  Yala Road Yala National Park BlockI Southern Province",
#     "District Secretariat  Hambanthota": "District Secretariat  Hambanthota",
#     "Divulpitiya Lake": "Divulpitiya Lake",
#     "Dole Aranya Kithulagoda Pitadeniya Pallekanda Southern": "Dole Aranya Kithulagoda Pitadeniya Pallekanda Southern",
#     "Double Tree Hilton Wirawila": "Double Tree Hilton Wirawila",
#     "Doubletree Hilton": "Doubletree Hilton",
#     "Dry Zone Botanic Gardens  Hambantota Southern Province": "Dry Zone Botanic Gardens Hambanthota Southern Province",
#     "Dry Zone Botanic Gardens Hambanthota Southern Province": "Dry Zone Botanic Gardens Hambanthota Southern Province",
#     "Dry Zone Botanical Garden": "Dry Zone Botanical Garden",
#     "E Southern Province": "Southern Province",
#     "E roadside": "E roadside",
#     "EgoSwargarajje": "EgoSwargarajje",
#     "Elephant Reach Hotel": "Elephant Reach Hotel",
#     "Embelicala lagoon  Bundala": "Bundala  Embilikala Lagoon",
#     "Embilikala  Bundala National Park": "Embilikala Bundala National Park",
#     "Embilikala Kalapuwa Wetland Bundula National Park": "Embilikala Kalapuwa Wetland Bundula National Park",
#     "Embilikala Lagoon": "Embilikala lagoon",
#     "Embilikala To Park Office Bundala National Park": "Embilikala To Park Office Bundala National Park",
#     "EmbilikalalSouthern Province": "EmbilikalalSouthern Province",
#     "Entrance Yala NP": "Entrance Yala NP",
#     "Fishing Village Pallemalala Hambantota Southern Province": "Fishing Village Pallemalala Hambantota Southern Province",
#     "Flameback lodge": "Flameback lodge",
#     "Flamingo Cottage": "flamingo cottage",
#     "Flamingo Cottages Bundala": "Bundala flamingo cottage",
#     "Forest Area Bundala National Park": "Forest Area Bundala National Park",
#     "Gal Wala Home Walasmulla Southern": "Gal Wala Home Walasmulla Southern",
#     "Galpotta Road Wakkariya Junction Bandagiriya": "Galpotta Road Wakkariya Junction Bandagiriya",
#     "Galpotta Road Wakkariya Junction Bandagiriya Southern Province": "Galpottha Road Wakkariya Junction Badagiriya Hambantota Southern Province",
#     "Galpottha Road Wakkariya Junction Badagiriya Hambantota": "Galpottha Road Wakkariya Junction Badagiriya Hambantota",
#     "Galpottha Road Wakkariya Junction Badagiriya Hambantota Southern Province": "Galpottha Road Wakkariya Junction Badagiriya Hambantota Southern Province",
#     "Gemunupura Debarawewa Southern Province": "Gemunupura Debarawewa Southern Province",
#     "Getamanna Road Beliatta  Southern Province": "Getamanna Road Beliatta  Southern Province",
#     "Godakalapuwa  Ruhuna NP": "Godakalapuwa  Ruhuna NP",
#     "Godakalapuwa Kirinda  Palatupana  Yala Road Southern Province": "Godakalapuwa Kirinda  Palatupana  Yala Road Southern Province",
#     "Godawaya": "Godawaya",
#     "Gona Widda Wewa Bundala Sanctuary Southern Province": "Gona Widda Wewa Bundala Sanctuary Southern Province",
#     "Goyam Bay": "Goyam Bay",
#     "Goyambokka තගලල දකණ පළත   Palm Paradice Hotel": "Goyambokka තගලල දකණ පළත   Palm Paradice Hotel",
#     "Grand Hotel Halabana": "Grand Hotel Halabana",
#     "Great Lake Villa Weerawila Lake": "Great Lake Villa Weerawila Lake",
#     "Gurupokuna  Kalametiya": "Gurupokuna  Kalametiya",
#     "Gurupokuna Rock  Kalametiya Southern Province": "Gurupokuna Rock  Kalametiya Southern Province",
#     "HRI Airport": "HRI Airport",
#     "Hambanthota Maha Lewaya": "Hambanthota Maha Lewaya",
#     "Hambanthota kalu dodol shops": "Hambanthota kalu dodol shops",
#     "Hambantota": "Hambantota",
#     "Hambantota  Bundala Road": "Hambantota  Bundala Road",
#     "Hambantota  Mirijjawila Dry Zone Botanical Gardens": "Hambantota  Mirijjawila Dry Zone Botanical Gardens",
#     "Hambantota E Southern Province": "Hambantota Southern Province",
#     "Hambantota Salt Pans": "Hambantota Salt Pans",
#     "Hambantota Southern Province": "Hambantota Southern Province",
#     "Hamlet": "Hamlet",
#     "Heenwewa Bungalow": "Heenwewa Bungalow",
#     "Hibiscus Garden Hotel Tissamaharama": "Hibiscus Garden Hotel Tissamaharama",
#     "Hotel ShangriLa Hambantota": "ShangriLa Hambantota Hotel",
#     "Hummanaya Blow Hole Kudawella Southern Province": "Hummanaya Blow Hole Kudawella Southern Province",
#     "Hungama  Gurupokuna Road Southern Province": "Hungama  Gurupokuna Road Southern Province",
#     "Hungama Post Office": "Hungama Post Office",
#     "Isuru Villa  Beliaththa": "Isuru Villa  Beliaththa",
#     "Jetwing Yala": "Yala Jetwing",
#     "Jetwing Yala  Palatupana Beach": "Jetwing Yala  Palatupana Beach",
#     "Jetwing Yala Hotel": "JETWING YALA HOTEL",
#     "Jetwing Yala Road Palatupana Southern Province": "Jetwing Yala Road Palatupana Southern Province",
#     "Jetwing Yala resort": "Jetwing Yala resort",
#     "Jul   am": "Jul   am",
#     "Kadurupokuna Road": "Kadurupokuna Road",
#     "Kahandamodara": "Kahandamodara",
#     "Kalamatiya Bird Sanctuary": "Kalametiya Bird Sanctuary",
#     "Kalamatiya Lagoon  Kalametiya Southern Province": "Kalamatiya Lagoon  Kalametiya Southern Province",
#     "Kalamatiya Road Kalametiya Southern Province": "Kalamatiya Road Kalametiya Southern Province",
#     "Kalametiya": "Kalametiya",
#     "Kalametiya Bird Sanctuary": "Kalametiya Bird Sanctuary",
#     "Kalametiya Lagoon Kalametiya Sri Lanka": "Kalametiya Lagoon Kalametiya Sri Lanka",
#     "Kalametiya Road": "Kalametiya Road",
#     "Kalametiya Sancruary": "Kalametiya Sancruary",
#     "Kalametiya Sanctuary Gurupokuna Side": "Kalametiya Sanctuary Gurupokuna Side",
#     "Kalametiya Sanctuary Lunama Lagoon": "Kalametiya Sanctuary Lunama Lagoon",
#     "Kalametiya Southern Province": "Kalametiya Southern Province",
#     "Kalametiya Village Southern": "Kalametiya Village Southern",
#     "Kalametiya plains": "Kalametiya plains",
#     "Karagan Lewaya": "Karagan Lewaya",
#     "Karagan Lewaya Hambanthota": "Karagan Lewaya Hambanthota",
#     "Katagamuwa Wildlife Sanctuary": "Katagamuwa Wildlife Sanctuary",
#     "Kataragama  Situlpawwa Road": "Kataragama  Situlpawwa Road",
#     "Kataragama  Situlpawwa Road Southern Province": "Kataragama  Situlpawwa Road Southern Province",
#     "Keliyapura Gonnoruwa Southern Province": "Keliyapura Gonnoruwa Southern Province",
#     "Keliyawalana Wewa Southern Province": "Keliyawalana Wewa Southern Province",
#     "Kirinda  Palatupana  Shrubs Patch": "Kirinda  Palatupana  Shrubs Patch",
#     "Kirinda  Palatupana  Yala Road Kirinda Southern Province": "Kirinda  Palatupana  Yala Road Kirinda Southern Province   Cozey Yala",
#     "Kirinda  Palatupana  Yala Road Kirinda Southern Province   Cozey Yala": "Kirinda  Palatupana  Yala Road Kirinda Southern Province   Cozey Yala",
#     "Kirinda  Palatupana  Yala Road Palatupana Southern Province": "Kirinda  Palatupana  Yala Road Palatupana Southern Province",
#     "Kirinda  Palatupana  Yala Road Southern Province": "Kirinda  Palatupana  Yala Road Southern Province",
#     "Kirinda  Palatupana  Yala Road Southern Province  Yala National Park Block": "Diganwala Palatupana  Yala Road Yala National Park BlockI Southern Province",
#     "Kirinda  Palatupana Road  Palatupana Entrance": "Kirinda  Palatupana Road  Palatupana Entrance",
#     "Kirinda  Situlpawwa  Katharagama road": "Kirinda  Situlpawwa  Katharagama road",
#     "Kirinda  Situlpawwa Road Southern Province": "Kirinda  Situlpawwa Road Southern Province",
#     "Kirinda Beach": "Kirinda Beach",
#     "Kirinda Lagoon": "Kirinda Lagoon",
#     "Kirinda Southern Province": "B Kirinda Southern Province",
#     "Kirinda Southern Province  cinnamon Wild Hotel": "Kirinda Southern Province  cinnamon Wild Hotel",
#     "KirindaPalatupanaYala Road Southern Province": "KirindaPalatupanaYala Road Southern Province",
#     "KirindaPalatupanaYala Road Yala National Park  Block": "KirindaPalatupanaYala Road Yala National Park  Block",
#     "KirindaYala roadPalatupana": "KirindaYala roadPalatupana",
#     "Kithala Resort": "Kithala Resort",
#     "Kithala Resort Tissamaharama Southern Province": "Kithala Resort Tissamaharama Southern Province",
#     "Koholankal Lewaya": "Koholankal Lewaya",
#     "Koma Wewa Yala National Park Block I Southern Province": "Koma Wewa Yala National Park Block I Southern Province",
#     "Koragaha Lodge": "Koragaha Lodge",
#     "Koravakwala Tank Yala National Park Block I Katagamuwa Entrance Southern Province": "Koravakwala Tank Yala National Park Block I Katagamuwa Entrance Southern Province",
#     "Kotasiyabale Yala National Park  Southern Province": "Kotasiyabale Yala National Park  Southern Province",
#     "Krindi Oya": "Krindi Oya",
#     "Kulu Safari": "Kulu Safari",
#     "Kulu Safaris Katagamuwa Southern Province": "Kulu Safaris Katagamuwa Southern Province",
#     "Lagoon Inn": "Lagoon Inn",
#     "Lagoon Paradise Beach Resort": "Lagoon Paradise Beach Resort",
#     "Lake Ibis  N  E": "Lake Ibis  N  E",
#     "Lake Road": "Lake Road",
#     "Lake Road Debarawewa Southern Province": "Lake Road Debarawewa Southern Province",
#     "Lake Road Tissamaharama Southern Province": "Lake Road Tissamaharama Southern Province",
#     "Lake Tissa eastnorth": "Lake Tissa eastnorth",
#     "Lake View Cottage  Tissamaharama": "Lake View Cottage  Tissamaharama",
#     "Lanka Salt Circuit Bungalow": "Lanka Salt Circuit Bungalow",
#     "Lavish Eco Lodge to Lake": "Lavish Eco Lodge to Lake",
#     "Laxman Rajapaksha Road Southern Province": "Laxman Rajapaksha Road Southern Province",
#     "Leopard Corridor Palatupana": "Leopard Corridor Palatupana",
#     "Lin thuna area  Vicinity": "Lin thuna area  Vicinity",
#     "Lunugamwehera": "Lunugamwehera",
#     "Lunugamwehera  Airport Road Southern Province": "Lunugamwehera  Airport Road Southern Province",
#     "Lunugamwehera Highway Road": "Lunugamwehera Highway Road",
#     "Lunungamwehera  Katarangama Road": "Lunungamwehera  Katarangama Road",
#     "Madilla Road Tangalle Southern Province": "Madilla Road Tangalle Southern Province",
#     "Madunagala Hot Water Spring Southern Province": "Madunagala Hot Water Spring Southern Province",
#     "Madunahala forest": "Madunahala forest",
#     "Mahaseelawa Lagoon Southern Province": "Mahaseelawa Lagoon Southern Province",
#     "Mahaseelawa Road Southern Province": "Mahaseelawa Road Southern Province",
#     "Mahasenpura Tissamaharama Southern Province": "Mahasenpura Tissamaharama Southern Province",
#     "Mahawala Lagoon Southern Province": "Mahawala Lagoon Southern Province",
#     "Malala Modara Southern Province": "Malala Modara Southern Province",
#     "Maliththanpelessa Rock Outcrop Wedihitikanda Forest Reserve Katharagama Southern Province": "Maliththanpelessa Rock Outcrop Wedihitikanda Forest Reserve Katharagama Southern Province",
#     "Mamadala": "Mamadala",
#     "Mangrove Beach Chalets": "Mangrove Beach Chalets",
#     "Marakolliya Tangalle": "Marakolliya Tangalle",
#     "Mattala Interchange Southern Expressway Southern Province": "Mattala Interchange Southern Expressway Southern Province",
#     "Mattala Rajapaksa International Airport": "Mattala Rajapaksa International Airport",
#     "Mattala Southern Province": "Mattala Southern Province",
#     "Mawalla Lagoon": "Mawalla Lagoon",
#     "Mawalla Lagoon  Morakatiyara Southern Province": "Mawalla Lagoon  Morakatiyara Southern Province",
#     "Mayasha Residence Uddakandara Sithulpawwa Road Tissamaharama": "Mayasha Residence Uddakandara Sithulpawwa Road Tissamaharama",
#     "Medilla Southern Province": "Medilla Southern Province",
#     "Medilla Tangalle": "Medilla Tangalle",
#     "Meegahajandura Suriyawewa Southern Province": "Meegahajandura Suriyawewa Southern Province",
#     "Menikganga Rest Stop Yala National Park block I Southern Province": "Menikganga Rest Stop Yala National Park block I Southern Province",
#     "Menikganga River Cross Warahana Yala National Park Block I Katagamuwa Entrance Southern Province": "Menikganga River Cross Warahana Yala National Park Block I Katagamuwa Entrance Southern Province",
#     "Menikganga to Katagamuwa Sanctuary Yala Block I Southern Province": "Menikganga to Katagamuwa Sanctuary Yala Block I Southern Province",
#     "Mirijjawila": "Mirijjawila",
#     "Mirijjawila Lewaya": "Mirijjawila Lewaya",
#     "Mirissa": "Mirissa",
#     "Modarawana Okewela  Southern": "Modarawana Okewela  Southern",
#     "Modarawana Okewela Southern Province": "Modarawana Okewela Southern Province",
#     "Moms Kitchen Tissamaharama Southern Province": "Moms Kitchen Tissamaharama Southern Province",
#     "Monaragala District Uva": "Monaragala District Uva",
#     "Moon Light Guest House": "Moon Light Guest House",
#     "Morakatiyara Southern Province": "Morakatiyara Southern Province",
#     "Mulkirigala Rock Monastry": "Mulkirigala Rock Monastry",
#     "Muruthawela Lake": "Muruthawela Lake",
#     "Muruthawela Tank": "Muruthawela Tank",
#     "Nakulugamuwa Paddy Fields": "Nakulugamuwa Paddy Fields",
#     "Nathuwala Walasmulla Southern": "Nathuwala Walasmulla Southern",
#     "Nature Lovers Resort Kirinda Southern Province": "Nature Lovers Resort Kirinda Southern Province",
#     "Netolpitiya  Rekawa Road Southern Province": "Netolpitiya  Rekawa Road Southern Province",
#     "Netolpitiya Southern Province": "Netolpitiya Southern Province",
#     "New Buthawa Wild Life Bungalow Yala National Park": "New Buthawa Wild Life Bungalow Yala National Park",
#     "New Buthawa Wildlife Bungalow Yala National Park Block  Southern Province": "Old Buthawa Wildlife Bungalow Yala National Park Block  Southern Province",
#     "New Buthawa Wildlife Bungalow Yala National Park Southern Province": "Old Buthawa Wildlife Bungalow Yala National Park Block  Southern Province",
#     "Nidangala Beach": "Nidangala Beach",
#     "Nidangala Beach Kirinda": "Nidangala Beach Kirinda",
#     "Nil Sisila Palatupana": "Nil Sisila Palatupana",
#     "Nimalawa Temple Road Kirinda": "Nimalawa Temple Road Kirinda",
#     "Nonagama Southern Province": "Nonagama Southern Province",
#     "Nov": "Nov",
#     "Nov    AM": "Nov    AM",
#     "Nov    PM": "Nov    PM",
#     "Nugasewana campsite vicinity": "Nugasewana campsite vicinity",
#     "Ocean Cottage": "Ocean Cottage",
#     "Oceans Edge": "Oceans Edge",
#     "Old Buthawa Wildlife Bungalow Yala National Park Block  Southern Province": "Old Buthawa Wildlife Bungalow Yala National Park Block  Southern Province",
#     "Padawkema  Mattala Road Southern Province": "Padawkema  Mattala Road Southern Province",
#     "Paddy Research Station  Ambalantota": "Paddy Research Station  Ambalantota",
#     "Palatupana": "Palatupana",
#     "Palatupana  Kirinda Yala NP Road": "Palatupana  Kirinda Yala NP Road",
#     "Palatupana Area": "Palatupana Area",
#     "Palatupana Beach Yala": "Palatupana Beach Yala",
#     "Palatupana Lewaya": "Palatupana Lewaya",
#     "Palatupana Saltern Bungalow": "Palatupana Saltern Bungalow",
#     "Palatupana Saltern Southern Province": "Palatupana Saltern Southern Province",
#     "Palatupana Salthern Bungalow  Sea Side": "Palatupana Salthern Bungalow  Sea Side",
#     "Palatupana Southern Province": "Palatupana Southern Province",
#     "Palatupana Southern Province  cinnomon  Wild": "Palatupana Southern Province  cinnomon  Wild",
#     "Palatupana WNPS Bungalow": "WNPS Yala Bungalow  Palatupana",
#     "Palatupana Wetland": "Palatupana Wetland",
#     "Palatupana lagoon": "Palatupana lagoon",
#     "Palatupana saltern": "Palatupana Saltern",
#     "Pallamelala Wela": "Pallamelala Wela",
#     "Pallemalala": "Pallemalala",
#     "Pallemalala Southern Province": "Pallemalala Wewa Southern Province",
#     "Pallemalala Wawa": "Pallemalala Wewa",
#     "Pallemalala Wawa Southern Province": "Pallemalala Wewa Southern Province",
#     "Pallemalala Wewa": "Pallemalala Wewa",
#     "Pallemalala Wewa Southern Province": "Pallemalala Wewa Southern Province",
#     "Pannegamuwa Lake": "Pannegamuwa Lake",
#     "Pannegamuwa Tank": "Pannegamuwa Tank",
#     "Patanangala Beach": "Patanangala Beach",
#     "Patanangala Resthouse Road": "Patanangala Resthouse Road",
#     "Patanangala Wewa Patanangala Resthouse Road Yala National Park Block Southern province": "Patanangala Wewa Patanangala Resthouse Road Yala National Park Block Southern province",
#     "Pattamaluwa Juntion Southern Province": "Pattamaluwa Juntion Southern Province",
#     "Pattiyawala Yala National Park Southern Province": "Pattiyawala Yala National Park Southern Province",
#     "Peacock Reach Hotel Tissamaharama Southern Province": "Peacock Reach Hotel Tissamaharama Southern Province",
#     "Pemdas Vila Yala National Park Block I Southern Province": "Pemdas Vila Yala National Park Block I Southern Province",
#     "Pennegamuwa Wirawila Southern Province": "Pennegamuwa Wirawila Southern Province",
#     "Pond  Rekawa": "Pond  Rekawa",
#     "Ponds next to ticket office": "Ponds next to ticket office",
#     "Punchi Akurugoda Tissamaharamaya Southern Province": "Punchi Akurugoda Tissamaharamaya Southern Province",
#     "Puwakdandawa Southern Province": "Puwakdandawa Southern Province",
#     "RajapuragodaUdadeniya Road Walasmulla Southern Province": "RajapuragodaUdadeniya Road Walasmulla Southern Province",
#     "Ranawaranawa Lake": "Ranawaranawa Lake",
#     "Ranna  Southern Express Way": "Ranna  Southern Express Way",
#     "Ranna Rivermouth Kahandamodera Beach Ranna Sri Lanka": "Ranna Rivermouth Kahandamodera Beach Ranna Sri Lanka",
#     "RannaLake Near Green Parrot Hotel": "RannaLake Near Green Parrot Hotel",
#     "RannaMeadow Near Mandala Villas": "RannaMeadow Near Mandala Villas",
#     "RannaRiver Mouth Near Kahandamodara Beach": "RannaRiver Mouth Near Kahandamodara Beach",
#     "Really Really Secret Beach": "Really Really Secret Beach",
#     "Rekawa": "Rekawa",
#     "Rekawa Lagoon": "Rekawa Lagoon",
#     "Rekawa Marsh": "Rekawa Marsh",
#     "Rekawa Road Southern Province": "Rekawa Road Southern Province",
#     "Rekawa Village  Surrounding Areas": "Rekawa Village  Surrounding Areas",
#     "Rekawawetlands": "Rekawawetlands",
#     "Ridiyagama Safari Park": "Ridiyagama Safari Park",
#     "Ridiyagama Safari Park Southern Province": "Ridiyagama Safari Park Southern Province",
#     "RidiyagamaUnnamed Road Southern Province": "RidiyagamaUnnamed Road Southern Province",
#     "River Walk Near Lake Debawarawa": "River Walk Near Lake Debawarawa",
#     "Riverside Hotels": "Riverside Hotels",
#     "Road Behind Debarawara Lake Sandungama Road Southern Province": "Road Behind Debarawara Lake Sandungama Road Southern Province",
#     "Road Southern Province": "Road Southern Province",
#     "Road Weligatta Southern Province": "Road Weligatta Southern Province",
#     "Rota Wewa Bundala Village Southern Province": "Rota Wewa Bundala Village Southern Province",
#     "RoverR Birding Tissamaharama": "RoverR Birding Tissamaharama",
#     "Rumba Viharaya": "Rumba Viharaya",
#     "SLOW   New Tangalle Road Tangalle Southern Province": "SLOW   New Tangalle Road Tangalle Southern Province",
#     "Sahanagama Rd Southern Province": "Sahanagama Rd Southern Province",
#     "Salter faced restaurent area": "Salter faced restaurent area",
#     "Saltern Bunglow to Wilmannar sanctuary  in side the sanctuary": "Saltern Bunglow to Wilmannar sanctuary  in side the sanctuary",
#     "Saltlake near Kalametiya": "Saltlake near Kalametiya",
#     "Samikuliya Wewa": "Samikuliya Wewa",
#     "Sandagirigama Sithulpawwa Road Southern Province": "Sandagirigama Sithulpawwa Road Southern Province",
#     "Sandungama Road Tissamaharama Southern Province": "Sandungama Road Tissamaharama Southern Province",
#     "Saradha Lagoon View": "Saradha Lagoon View",
#     "Seadawatta Wirawila Southern Province": "Seadawatta Wirawila Southern Province",
#     "Senasuma Wetland": "Senasuma Wetland",
#     "ShangriLAs Hambantota": "ShangriLAs Hambantota",
#     "ShangriLa Hambantota Hotel": "ShangriLa Hambantota Hotel",
#     "ShangriLa resort hambantota": "ShangriLa resort hambantota",
#     "Sithpawwa Road": "Sithpawwa Road",
#     "Sithulpahuwa Monastery  KirindaSitulpawwa Road Situlpawwa Southern Province": "Sithulpahuwa Monastery  KirindaSitulpawwa Road Situlpawwa Southern Province",
#     "Sithulpawwa": "Situlpawwa",
#     "Sithulpawwa Road Sri Lanka": "Sithulpawwa Road Sri Lanka",
#     "Situlpawwa": "Situlpawwa",
#     "Smal pond near Rekawa": "Smal pond near Rekawa",
#     "Southern Expressway Southern Province": "Southern Expressway Southern Province",
#     "Southern Province": "Southern Province",
#     "Southern Province   Bundala Salt Marsh": "Southern Province   Bundala Salt Marsh",
#     "Southern Province  In Front Of The Guest House": "Southern Province  In Front Of The Guest House",
#     "Southern Province Southern Province": "Southern Province Southern Province",
#     "Southern Province Southern Province WeerawilA Hilton hotel": "Southern Province Southern Province WeerawilA Hilton hotel",
#     "Southern ProvinceColombo  Galle  Hambantota  Wellawaya Road": "Southern ProvinceColombo  Galle  Hambantota  Wellawaya Road",
#     "Southern ProvinceKirindaPalatupanaYala Road": "Southern ProvinceKirindaPalatupanaYala Road",
#     "Sri Kawanthissa Vocational Training Center": "Sri Kawanthissa Vocational Training Center",
#     "Sri Lanka  Cinnamon Wild Yala": "Sri Lanka  Cinnamon Wild Yala",
#     "Sri Lanka  Tissa Lake Area": "Sri Lanka  Tissa Lake Area",
#     "Sri Lanka  Tissa Lake Flying Fox Hotspot": "Sri Lanka  Tissa Lake Flying Fox Hotspot",
#     "Sri Lanka Yala National Park Block": "Yala National Park Sri Lanka",
#     "Sri LankaEKHO Safari Tissa": "Sri LankaEKHO Safari Tissa",
#     "Sw": "Sw",
#     "TD Road": "TD Road",
#     "TERN Dry Zone Field Station": "TERN Dry Zone Field Station",
#     "Tangalla  Marshes": "Tangalla  Marshes",
#     "Tangalla Prowincja Południowa": "Tangalla Prowincja Południowa",
#     "Tangalla Rest House": "Tangalla Rest House",
#     "Tangalle": "Tangalle",
#     "Tangalle Beach": "Tangalle Beach",
#     "Tangalle Paddy fields": "Tangalle Paddy fields",
#     "Tangalle Paddyfields  West side": "Tangalle Paddyfields  West side",
#     "Tangalle Tangalle Southern Province": "Tangalle Tangalle Southern Province",
#     "Tangalle Villa": "Tangalle Villa",
#     "Tangalle Wella": "Tangalle Wella",
#     "Taragala chalets Tangalle Southern Province": "Taragala chalets Tangalle Southern Province",
#     "Taru Villas Mawella": "Taru Villas Mawella",
#     "Telulla Archaeological Site": "Telulla Archaeological Site",
#     "Thalgasmankada Yala National Park": "Thalgasmankada Yala National Park",
#     "Thalgasmankada Yala National Park Block": "Thalgasmankada Yala National Park",
#     "ThalgasmankadaYala National Park": "Thalgasmankada Yala National Park",
#     "Thanamalwila  Tranquil Wild": "Thanamalwila  Tranquil Wild",
#     "Thangalle Marsh": "Thangalle Marsh",
#     "Thanjanagar Mahasenpura Tissamaharama Southern Province": "Thanjanagar Mahasenpura Tissamaharama Southern Province",
#     "Thissa  Kataragama Road chef lady": "Thissa  Kataragama Road chef lady",
#     "Thissa Reservoir  Flood Zone Thissamaharama Southern Province": "Thissa Reservoir  Flood Zone Thissamaharama Southern Province",
#     "Thissa lake": "Tissa Lake",
#     "Thissamahara  surroundings": "Thissamahara  surroundings",
#     "Thissamaharama Stupa temple": "Thissamaharama Stupa temple",
#     "Tissa  Kirinde Road Southern Province": "Tissa  Kirinde Road Southern Province",
#     "Tissa Lake": "Tissa Lake",
#     "Tissa Lake North": "Tissa Lake North",
#     "Tissa Rd Weligatta Southern": "Tissa Rd Weligatta Southern",
#     "Tissa Road Debarawewa Southern Province": "Tissa Road Debarawewa Southern Province",
#     "Tissa Road Hungama Southern Province": "Tissa Road Hungama Southern Province",
#     "Tissa Road Southern Province": "Tissa Road Southern Province",
#     "Tissa Road Tissamaharama Southern Province": "Tissa Road Tissamaharama Southern Province",
#     "Tissa Tank Tissamaharama Southern Province": "Tissa Tank Tissamaharama Southern Province",
#     "Tissa maharama": "Tissa maharama",
#     "Tissa wetland Tissamaharamaya": "Tissa wetland Tissamaharamaya",
#     "Tissamaharam Road Hambantota Southern Province": "Tissamaharam Road Hambantota Southern Province",
#     "Tissamaharam Road Southern Province": "Tissa Road Tissamaharama Southern Province",
#     "Tissamaharam Road Weligatta Southern Province": "Tissamaharam Road Weligatta Southern Province",
#     "Tissamaharama": "Tissamaharama",
#     "Tissamaharama General": "Tissamaharama General",
#     "Tissamaharama Southern Province": "Tissamaharama Southern Province",
#     "Tissamaharama general area": "Tissamaharama general area",
#     "Tissamaharama lakes  around": "Tissamaharama lakes  around",
#     "Tissamaharama to Bundala NP": "Tissamaharama to Bundala NP",
#     "Tissamaharama_Chaarya Hotel  Spa": "Tissamaharama_Chaarya Hotel  Spa",
#     "Tranquil Wild": "Tranquil Wild",
#     "Tranquil Wild Thanamalwila": "Thanamalwila  Tranquil Wild",
#     "Tranquill Wild Southern Province": "Tranquill Wild Southern Province",
#     "Treasure Rock Guest House": "Treasure Rock Guest House",
#     "Treasure Rock Kirinda": "Treasure Rock Kirinda",
#     "Tribe Yala": "Tribe Yala",
#     "Tribe Yala Resort": "Tribe Yala Resort",
#     "Turtle Bay Kalametiya": "Turtle Bay Kalametiya",
#     "Turtle Bay hotel Kalametiya": "Turtle Bay hotel Kalametiya",
#     "Turtle Paradise Hotel": "Turtle Paradise Hotel",
#     "Turtle Point Beach": "Turtle Point Beach",
#     "Turtle Watch Rekawa": "Turtle Watch Rekawa",
#     "Turtles view Resort": "Turtles view Resort",
#     "UCIARS Weligatta Southern Province": "UCIARS Weligatta Southern Province",
#     "Uda Maththala Southern Province": "Uda Maththala Southern Province",
#     "Udamalala Tissamaharam Road Southern Province": "Udamalala Tissamaharam Road Southern Province",
#     "Udawila Wewa Southern Province": "Udawila Wewa Southern Province",
#     "Udukiriwala Wewa": "Udukiriwala Wewa",
#     "Unakuruwa": "Unakuruwa",
#     "Unnamed Road Andarawewa Southern Province": "Unnamed Road Southern Province   Banduwewa",
#     "Unnamed Road Hambantota Southern Province": "Unnamed Road Hambantota Southern Province",
#     "Unnamed Road Mahasenpura Southern Province": "Unnamed Road Mahasenpura Southern Province",
#     "Unnamed Road Southern Province": "Unnamed Road Southern Province",
#     "Unnamed Road Southern Province   Banduwewa": "Unnamed Road Southern Province   Banduwewa",
#     "Unnamed Road Southern Province   Ranketha Eco Safari": "Unnamed Road Southern Province   Ranketha Eco Safari",
#     "Unnamed Road Southern Province  Yala National Park Block": "Unnamed Road Southern Province  Yala National Park Block",
#     "Urania National park area": "Urania National park area",
#     "Urania village from the saltern Bunglow": "Urania village from the saltern Bunglow",
#     "Uraniya Wewa  Surrounding Vicinity": "Uraniya Wewa  Surrounding Vicinity",
#     "Ussangoda Beach": "Ussangoda Beach",
#     "Ussangoda National Park": "Ussangoda National Park",
#     "Ussangoda National Park Ambalantota Sri Lanka": "Ussangoda National Park Ambalantota Sri Lanka",
#     "Ussangoda Southern Province": "Ussangoda Southern Province",
#     "Villa Tanderra": "Villa Tanderra",
#     "Voccational Training Centre Tissamaharama": "Voccational Training Centre Tissamaharama",
#     "WNPS Yala Bungalow": "WNPS Yala Bungalow",
#     "WNPS Yala Bungalow  Palatupana": "WNPS Yala Bungalow  Palatupana",
#     "Wadula Lodge": "Wadula Lodge",
#     "Wakamulla": "Wakamulla",
#     "Wakkariya Junction Badagiriya Hambantota": "Wakkariya Junction Badagiriya Hambantota",
#     "Walasmulla Southern Province": "Walasmulla Southern Province",
#     "Walatta Villa": "Walatta Villa",
#     "Waligatta to Bundala  Southern Province": "Waligatta to Bundala  Southern Province",
#     "Waligatta wewa Tissamaharam Road Southern Province": "Tissamaharam Road Weligatta Southern Province",
#     "Warahana  Thalgasmankada Southern Province": "Warahana  Thalgasmankada Southern Province",
#     "Warapitiya Lake": "Warapitiya Lake",
#     "Wedasitikanda Forest Reserve Border  Malittanpelessa Wewa": "Wedasitikanda Forest Reserve Border  Malittanpelessa Wewa",
#     "Weerawila Dam": "Weerawila Dam",
#     "Weerawila Lake Southern ProvincePannegamuwaTissaKataragama Road": "Weerawila Lake Southern ProvincePannegamuwaTissaKataragama Road",
#     "Weerawila Tank Southern Province": "Weerawila Tank Southern Province",
#     "Weliaragoda Wetland": "Weliaragoda Wetland",
#     "Weligaththa bundala road": "Weligaththa bundala road",
#     "Weligatta Southern Province": "Road Weligatta Southern Province",
#     "Weligatta junction from the saltern bungalow": "Weligatta junction from the saltern bungalow",
#     "Welmalkema  Yala NP": "Welmalkema  Yala NP",
#     "Wewa  Bundala National ParkSouthern Province": "Bundala National ParkSouthern province",
#     "Wewa  Unnamed Road Southern Province": "Unnamed Road Southern Province",
#     "Whispering House": "Whispering House",
#     "Wilapalawa Yala National Park Southern Province": "Wilapalawa Yala National Park Southern Province",
#     "Wild Coast Tented Lodge Yala": "Wild Coast Tented Lodge Yala",
#     "Wild Heaven hotel": "Wild Heaven hotel",
#     "Wild Lotus": "Wild Lotus",
#     "Wild Lotus Yala": "Wild Lotus Yala",
#     "Wild Trails Yala": "Wild Trails Yala",
#     "Will Anna Bundala": "Will Anna Bundala",
#     "Wilmanna Sanctuary Southern Province": "Wilmanna Sanctuary Southern Province",
#     "Wilmanna sanctuary along the Kirinda road": "Wilmanna sanctuary along the Kirinda road",
#     "Wilmannar sanctuary": "Wilmannar sanctuary",
#     "Wirawila": "Wirawila",
#     "Wirawila Lake Southern Province": "Wirawila Southern Province",
#     "Wirawila Southern Province": "Wirawila Southern Province",
#     "Wirawila Tissa Sanctuary": "Wirawila Tissa Sanctuary",
#     "Wirawila lake": "Wirawila lake",
#     "YALA NP  Block": "YALA NP  Block",
#     "Yahangala Archaeological Ruine Site Hambantota  Southern Province": "Yahangala Archaeological Ruine Site Hambantota  Southern Province",
#     "Yala": "Yala",
#     "Yala Beach Nature Resort Palatupana Southern Province": "Yala Beach Nature Resort Palatupana Southern Province",
#     "Yala Block": "Yala Block",
#     "Yala Entry Gate Southern Province": "Yala Entry Gate Southern Province",
#     "Yala Jetwing": "Yala Jetwing",
#     "Yala Katagamuwa Southern Province": "Yala Katagamuwa Southern Province",
#     "Yala NP": "Yala NP",
#     "Yala NP  Katagamuwa To Akasa Chaithya": "Yala NP  Katagamuwa To Akasa Chaithya",
#     "Yala NP Katagamuwa Entrance Sri Lanka": "Yala NP Katagamuwa Entrance Sri Lanka",
#     "Yala NP block I From Y junction To Sithulpawwa Road Southern Province": "Yala NP block I From Y junction To Sithulpawwa Road Southern Province",
#     "Yala NP entrance area": "Yala NP entrance area",
#     "Yala NPKatagamuwa": "Yala NPKatagamuwa",
#     "Yala NPPatanangala beach  picnic area": "Yala NPPatanangala beach  picnic area",
#     "Yala National Park": "Yala National Park",
#     "Yala National Park  Palatupana Entrance Southern Province": "Yala National Park  Palatupana Entrance Southern Province",
#     "Yala National Park Block": "Yala National Park Block II",
#     "Yala National Park Block  Southern Province": "Yala National Park Southern Province",
#     "Yala National Park Block I Katagamuwa Entrance Southern Province": "Yala National Park Block I Katagamuwa Entrance Southern Province",
#     "Yala National Park Block I Palatupana Entrance Southern Province": "Yala National Park  Palatupana Entrance Southern Province",
#     "Yala National Park Block I Sathmanga Modaragala to Pemdasvila Road Southern Province": "Yala National Park Block I Sathmanga Modaragala to Pemdasvila Road Southern Province",
#     "Yala National Park Block II": "Yala National Park Block II",
#     "Yala National Park Block V  Palatupana  Via Heenwewa Section  Katagamuwa Entrance Upto Koma Wewa  Southern Province": "Yala National Park Block V  Palatupana  Via Heenwewa Section  Katagamuwa Entrance Upto Koma Wewa  Southern Province",
#     "Yala National Park General": "Yala National Park General",
#     "Yala National Park Hambantota": "Yala National Park Hambantota",
#     "Yala National Park Katagamuwa Entrance": "Yala National Park Katagamuwa Entrance",
#     "Yala National Park Katagamuwa Entrance Kataragama Southern Province": "Yala National Park Katagamuwa Entrance Kataragama Southern Province",
#     "Yala National Park Southern Province": "Yala National Park Southern Province",
#     "Yala National Park Sri Lanka": "Yala National Park Sri Lanka",
#     "Yala National ParkSri Lanka": "Yala National Park Sri Lanka",
#     "Yala Natl Park Block I": "Yala Natl Park Block I",
#     "Yala New Buthawa Southern Province": "Yala New Buthawa Southern Province",
#     "Yala Old Buthawa Bungalow  Southern Province": "Yala Old Buthawa Bungalow  Southern Province",
#     "Yala Old Buthawa Southern Province": "Yala New Buthawa Southern Province",
#     "Yala Palatupana Entarnce to Mahaseelawa Southern Province": "Yala Palatupana Entarnce to Mahaseelawa Southern Province",
#     "Yala Palatupana Entrance Area": "Yala Palatupana Entrance Area",
#     "Yala Saltern  Palatupana": "Yala Saltern  Palatupana",
#     "Yala Southern Province": "Yala Southern Province",
#     "Yala Sri Lanka Southern Province": "Yala Sri Lanka Southern Province",
#     "Yala Wewa Reservoir Yala National Park  Block I Southern Province": "Yala Wewa Reservoir Yala National Park  Block I Southern Province",
#     "Yala block  General": "Yala block  General",
#     "Yala buffer zone": "Yala buffer zone",
#     "Yala entrance roads  around": "Yala entrance roads  around",
#     "Yala palatupana entrance": "Yala Palatupana Entrance Area",
#     "Yala surroundings near jeep yard": "Yala surroundings near jeep yard",
#     "Yala to Setulpawwa Road Southern Province": "Yala to Setulpawwa Road Southern Province",
#     "Yoda Kandiya Tank": "Yoda Kandiya Tank",
#     "Yoda Lake": "Yoda Lake",
#     "Yoda Lake Southern Province": "Yoda Lake Southern Province",
#     "Yoda Lake Tissa": "Yoda Lake Tissa",
#     "Yodha Wewa Southern Province": "Yodha Wewa Southern Province",
#     "Zuidelijke Provincie": "Zuidelijke Provincie",
#     "bundala": "bundala",
#     "flameback": "flameback",
#     "kalamatiya Sanctuary": "Kalametiya Sancruary",
#     "kirinda": "kirinda",
#     "kl park": "kl park",
#     "nd Plain Kalametiya Southern Province": "st Plain Kalametiya Southern Province",
#     "nd PlainKalamatiya Road Kalametiya": "st PlainKalamatiya Road Kalametiya",
#     "road to the bird park": "road to the bird park",
#     "st Plain Kalametiya Southern Province": "st Plain Kalametiya Southern Province",
#     "st PlainKalamatiya Road Kalametiya": "st PlainKalamatiya Road Kalametiya",
#     "yalla": "yalla",
#     "භමඛනතට දකණ පළත": "භමඛනතට දකණ පළත",
#     "南部省": "南部省",
#     "南部省 南部省": "南部省 南部省",
# }
